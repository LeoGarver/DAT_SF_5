# %%
import numpy as np

# %%
import pandas as pd

# %%
pd.read_csv("titanic-train.csv")
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
# 15           16         1       2
# 16           17         0       3
# 17           18         1       2
# 18           19         0       3
# 19           20         1       3
# 20           21         0       2
# 21           22         1       2
# 22           23         1       3
# 23           24         1       1
# 24           25         0       3
# 25           26         1       3
# ...

# %%
db=pd.read_csv("titanic-train.csv")

# %%
#1. How many passengers are in our passenger list? 
#From here forward, we’ll assume our dataset represents the full passenger list for the Titanic.

# %%
print db.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# dtype: int64

# %%
#1. There are 891 passengers in our passenger list

# %%
#2. What is the overall survival rate?

# %%
print db.Survived.mean()
# Out:
# 0.383838383838

# %%
#2. 38.4% of the Titanic Passengers survived.

# %%
#3. How many male passengers were onboard?
#4. How many female passengers were onboard?

# %%
male = db['Sex'] == 'male'
print db[male].count()
# Out:
# PassengerId    577
# Survived       577
# Pclass         577
# Name           577
# Sex            577
# Age            453
# SibSp          577
# Parch          577
# Ticket         577
# Fare           577
# Cabin          107
# Embarked       577
# dtype: int64

# %%
female = db['Sex'] == 'female'
print db[female].count()
# Out:
# PassengerId    314
# Survived       314
# Pclass         314
# Name           314
# Sex            314
# Age            261
# SibSp          314
# Parch          314
# Ticket         314
# Fare           314
# Cabin           97
# Embarked       312
# dtype: int64

# %%
#3. and 4. There were 577 male passengers and 314 female passengers onboar the ship

# %%
#5. What is the overall survival rate of male passengers?
#6. What is the overall survival rate of female passengers?

# %%
print db[male].Survived.mean()
# Out:
# 0.188908145581

# %%
print db[female].Survived.mean()
# Out:
# 0.742038216561

# %%
#5. The Male passenger survival rate was 18.9%
#6. The Female passenger survival rate was 74.2%

# %%
#7. What is the average age of all passengers onboard?
#a. How did you calculate this average age?
#b. Did you encounter any problems with this calculation?
#c. If so, how did you address any problems?

# %%
print db.Age.mean()
# Out:
# 29.6991176471

# %%
#7. The Average age is 29.7 years old

# %%
#8. What is the average age of passengers who survived?
#9. What is the average age of passengers who did not survive?

# %%
Alive = db['Survived'] == 1
print db[Alive].Age.mean()
# Out:
# 28.3436896552

# %%
Perished = db['Survived'] == 0
print db[Perished].Age.mean()
# Out:
# 30.6261792453

# %%
#8. Passengers who survived were an average age of 28.3 years old
#9. Passengers who died were an average age of 30.6 years old

# %%
#10. At this (early) point in our analysis, what might you infer about any patterns
#you are seeing?

# %%
#10. Female passengers were much more likely to survive than male passengers.
# On average, survivors tended to be slightly younger than the deceased.

# %%
#11. How many passengers are in each of the three classes of service 
#(e.g. First, Second, Third?)

# %%
First = db['Pclass'] == 1
Second = db['Pclass'] == 2
Third = db['Pclass'] ==3
print db[First].count()
print db[Second].count()
print db[Third].count()
# Out:
# PassengerId    216
# Survived       216
# Pclass         216
# Name           216
# Sex            216
# Age            186
# SibSp          216
# Parch          216
# Ticket         216
# Fare           216
# Cabin          176
# Embarked       214
# dtype: int64
# PassengerId    184
# Survived       184
# Pclass         184
# Name           184
# Sex            184
# Age            173
# SibSp          184
# Parch          184
# Ticket         184
# Fare           184
# Cabin           16
# Embarked       184
# dtype: int64
# PassengerId    491
# Survived       491
# Pclass         491
# Name           491
# Sex            491
# Age            355
# SibSp          491
# Parch          491
# Ticket         491
# Fare           491
# Cabin           12
# Embarked       491
# dtype: int64

# %%
#11. There were 216 passengers in First Class, 184 in Second and 491 in Third

# %%
#12 What is the survival rate for passengers in each of the three classes of service?

# %%
print db[First].Survived.mean()
print db[Second].Survived.mean()
print db[Third].Survived.mean()
# Out:
# 0.62962962963
# 0.472826086957
# 0.242362525458

# %%
#12. The survival rate for first-class passengers was 63.0%, 47.3% for those in second class, and 24.2% for those in Third.

# %%
#13. Continuing with 10, what else might you conclude?

# %%
#13. Passengers were more likely to survive if they were in a higher class of service.

# %%
#14 Last, if we were to build a predictive model, which features in the data do you
#think we should include in the model and which can we leave out? Why?

# %%
#14. For a predictive model, we should definitely include the passengers' sex and class of service because both of these factors
#seem to have a large difference on a person's survival chances.
#Age seems to have very little correlation with whether or not a person survived, so we can probably leave this out of our model.
